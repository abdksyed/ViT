# %%
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

plt.ion()   # interactive mode

# %% [markdown]
# Loading the data
# ----------------

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training dataset
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2434, 0.2615))
                   ])), batch_size=64, shuffle=True, num_workers=2)
# Test dataset
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2434, 0.2615))
    ])), batch_size=64, shuffle=True, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to .

# %% [markdown]
# Spatial Transformer Network
# --------------------------------------

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(500, 50)
        self.fc2 = nn.Linear(50, 10)

        # Spatial transformer localization-network
        self.localization = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 4 * 4, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 4 * 4)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)

        grid = F.affine_grid(theta, x.size(), align_corners=False)
        x = F.grid_sample(x, grid, align_corners=False)

        return x

    def forward(self, x):
        # transform the input
        x = self.stn(x)

        # Perform the usual forward pass
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 500)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


model = Net().to(device)

# %%
from torchsummary import summary
model = Net().to(device)
summary(model, (3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 26, 26]           1,184
#          MaxPool2d-2            [-1, 8, 13, 13]               0
#               ReLU-3            [-1, 8, 13, 13]               0
#             Conv2d-4             [-1, 10, 9, 9]           2,010
#          MaxPool2d-5             [-1, 10, 4, 4]               0
#               ReLU-6             [-1, 10, 4, 4]               0
#             Linear-7                   [-1, 32]           5,152
#               ReLU-8                   [-1, 32]               0
#             Linear-9                    [-1, 6]             198
#            Conv2d-10           [-1, 10, 28, 28]             760
#            Conv2d-11           [-1, 20, 10, 10]           5,020
#         Dropout2d-12           [-1, 20, 10, 10]               0
#            Linear-13                   [-1, 50]          25,050
#            Linear-14                   [-1, 10]             510
# ================================================================
# Total params: 39,884
# Trainable params: 39,884
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.33
# ----------------------------------------------------------------

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's use the SGD algorithm to train the model. The network is
# learning the classification task in a supervised way. In the same time
# the model is learning STN automatically in an end-to-end fashion.

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 781 == 0:
            print('Train Epoch: {} [({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, 100. * batch_idx / len(train_loader), loss.item()))


def test():
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)

            # sum up batch loss
            test_loss += F.nll_loss(output, target, size_average=False).item()
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'
              .format(test_loss, correct, len(test_loader.dataset),
                      100. * correct / len(test_loader.dataset)))

# %% [markdown]
# Visualizing the STN results
# ---------------------------
#
# Now, we will inspect the results of our learned visual attention
# mechanism.
#
# We define a small helper function in order to visualize the
# transformations while training.

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# We want to visualize the output of the spatial transformers layer
# after the training, we visualize a batch of input images and
# the corresponding transformed batch using STN.


def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        data = next(iter(test_loader))[0].to(device)

        input_tensor = data.cpu()
        transformed_input_tensor = model.stn(data).cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2)
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')


for epoch in range(1, 50 + 1):
    train(epoch)
    test()

# Visualize the STN transformation on some input batch
visualize_stn()

plt.ioff()
plt.show()
# Out:
# Train Epoch: 1 [(0%)]	Loss: 2.324855
# Train Epoch: 1 [(100%)]	Loss: 2.021944
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Average loss: 2.0397, Accuracy: 3022/10000 (30%)
#
# Train Epoch: 2 [(0%)]	Loss: 2.187143
# Train Epoch: 2 [(100%)]	Loss: 2.076536
#
# Test set: Average loss: 1.8396, Accuracy: 3599/10000 (36%)
#
# Train Epoch: 3 [(0%)]	Loss: 1.926664
# Train Epoch: 3 [(100%)]	Loss: 1.844328
#
# Test set: Average loss: 1.7075, Accuracy: 3902/10000 (39%)
#
# Train Epoch: 4 [(0%)]	Loss: 1.876936
# Train Epoch: 4 [(100%)]	Loss: 1.796036
#
# Test set: Average loss: 1.6418, Accuracy: 4201/10000 (42%)
#
# Train Epoch: 5 [(0%)]	Loss: 1.747470
# Train Epoch: 5 [(100%)]	Loss: 1.795877
#
# Test set: Average loss: 1.5806, Accuracy: 4352/10000 (44%)
#
# Train Epoch: 6 [(0%)]	Loss: 1.578922
# Train Epoch: 6 [(100%)]	Loss: 1.516216
#
# Test set: Average loss: 1.5445, Accuracy: 4509/10000 (45%)
#
# Train Epoch: 7 [(0%)]	Loss: 1.507220
# Train Epoch: 7 [(100%)]	Loss: 1.489026
#
# Test set: Average loss: 1.5134, Accuracy: 4554/10000 (46%)
#
# Train Epoch: 8 [(0%)]	Loss: 1.579045
# Train Epoch: 8 [(100%)]	Loss: 1.561023
#
# Test set: Average loss: 1.4886, Accuracy: 4708/10000 (47%)
#
# Train Epoch: 9 [(0%)]	Loss: 1.887913
# Train Epoch: 9 [(100%)]	Loss: 1.690020
#
# Test set: Average loss: 1.4495, Accuracy: 4739/10000 (47%)
#
# Train Epoch: 10 [(0%)]	Loss: 1.707817
# Train Epoch: 10 [(100%)]	Loss: 1.758919
#
# Test set: Average loss: 1.4316, Accuracy: 4883/10000 (49%)
#
# Train Epoch: 11 [(0%)]	Loss: 1.664179
# Train Epoch: 11 [(100%)]	Loss: 1.350789
#
# Test set: Average loss: 1.4042, Accuracy: 4954/10000 (50%)
#
# Train Epoch: 12 [(0%)]	Loss: 1.492649
# Train Epoch: 12 [(100%)]	Loss: 2.453726
#
# Test set: Average loss: 1.5633, Accuracy: 4430/10000 (44%)
#
# Train Epoch: 13 [(0%)]	Loss: 2.013850
# Train Epoch: 13 [(100%)]	Loss: 1.638107
#
# Test set: Average loss: 1.3908, Accuracy: 4984/10000 (50%)
#
# Train Epoch: 14 [(0%)]	Loss: 1.673364
# Train Epoch: 14 [(100%)]	Loss: 1.511660
#
# Test set: Average loss: 1.4444, Accuracy: 4783/10000 (48%)
#
# Train Epoch: 15 [(0%)]	Loss: 1.733510
# Train Epoch: 15 [(100%)]	Loss: 2.206886
#
# Test set: Average loss: 1.3534, Accuracy: 5159/10000 (52%)
#
# Train Epoch: 16 [(0%)]	Loss: 1.398647
# Train Epoch: 16 [(100%)]	Loss: 0.933099
#
# Test set: Average loss: 1.3486, Accuracy: 5103/10000 (51%)
#
# Train Epoch: 17 [(0%)]	Loss: 1.602681
# Train Epoch: 17 [(100%)]	Loss: 1.743304
#
# Test set: Average loss: 1.3458, Accuracy: 5214/10000 (52%)
#
# Train Epoch: 18 [(0%)]	Loss: 1.584730
# Train Epoch: 18 [(100%)]	Loss: 1.453718
#
# Test set: Average loss: 1.3079, Accuracy: 5250/10000 (52%)
#
# Train Epoch: 19 [(0%)]	Loss: 1.650526
# Train Epoch: 19 [(100%)]	Loss: 1.603728
#
# Test set: Average loss: 1.3955, Accuracy: 4943/10000 (49%)
#
# Train Epoch: 20 [(0%)]	Loss: 1.574089
# Train Epoch: 20 [(100%)]	Loss: 1.131145
#
# Test set: Average loss: 1.2979, Accuracy: 5386/10000 (54%)
#
# Train Epoch: 21 [(0%)]	Loss: 1.452785
# Train Epoch: 21 [(100%)]	Loss: 1.462788
#
# Test set: Average loss: 1.2743, Accuracy: 5479/10000 (55%)
#
# Train Epoch: 22 [(0%)]	Loss: 1.645172
# Train Epoch: 22 [(100%)]	Loss: 1.499506
#
# Test set: Average loss: 1.2800, Accuracy: 5424/10000 (54%)
#
# Train Epoch: 23 [(0%)]	Loss: 1.425907
# Train Epoch: 23 [(100%)]	Loss: 1.355747
#
# Test set: Average loss: 1.3105, Accuracy: 5320/10000 (53%)
#
# Train Epoch: 24 [(0%)]	Loss: 1.615891
# Train Epoch: 24 [(100%)]	Loss: 1.866403
#
# Test set: Average loss: 1.2949, Accuracy: 5407/10000 (54%)
#
# Train Epoch: 25 [(0%)]	Loss: 1.407569
# Train Epoch: 25 [(100%)]	Loss: 1.468515
#
# Test set: Average loss: 1.2560, Accuracy: 5586/10000 (56%)
#
# Train Epoch: 26 [(0%)]	Loss: 1.442166
# Train Epoch: 26 [(100%)]	Loss: 1.458748
#
# Test set: Average loss: 1.2524, Accuracy: 5576/10000 (56%)
#
# Train Epoch: 27 [(0%)]	Loss: 1.261744
# Train Epoch: 27 [(100%)]	Loss: 1.471873
#
# Test set: Average loss: 1.2265, Accuracy: 5595/10000 (56%)
#
# Train Epoch: 28 [(0%)]	Loss: 1.428162
# Train Epoch: 28 [(100%)]	Loss: 1.437238
#
# Test set: Average loss: 1.2312, Accuracy: 5669/10000 (57%)
#
# Train Epoch: 29 [(0%)]	Loss: 1.191184
# Train Epoch: 29 [(100%)]	Loss: 1.170035
#
# Test set: Average loss: 1.2361, Accuracy: 5624/10000 (56%)
#
# Train Epoch: 30 [(0%)]	Loss: 1.416839
# Train Epoch: 30 [(100%)]	Loss: 1.636734
#
# Test set: Average loss: 1.2144, Accuracy: 5756/10000 (58%)
#
# Train Epoch: 31 [(0%)]	Loss: 1.448721
# Train Epoch: 31 [(100%)]	Loss: 1.364435
#
# Test set: Average loss: 1.2026, Accuracy: 5677/10000 (57%)
#
# Train Epoch: 32 [(0%)]	Loss: 1.329916
# Train Epoch: 32 [(100%)]	Loss: 1.529729
#
# Test set: Average loss: 1.2137, Accuracy: 5630/10000 (56%)
#
# Train Epoch: 33 [(0%)]	Loss: 1.147635
# Train Epoch: 33 [(100%)]	Loss: 1.193943
#
# Test set: Average loss: 1.1965, Accuracy: 5811/10000 (58%)
#
# Train Epoch: 34 [(0%)]	Loss: 1.510273
# Train Epoch: 34 [(100%)]	Loss: 1.377153
#
# Test set: Average loss: 1.2213, Accuracy: 5686/10000 (57%)
#
# Train Epoch: 35 [(0%)]	Loss: 1.403630
# Train Epoch: 35 [(100%)]	Loss: 1.170191
#
# Test set: Average loss: 1.2278, Accuracy: 5628/10000 (56%)
#
# Train Epoch: 36 [(0%)]	Loss: 1.468940
# Train Epoch: 36 [(100%)]	Loss: 1.670198
#
# Test set: Average loss: 1.1857, Accuracy: 5794/10000 (58%)
#
# Train Epoch: 37 [(0%)]	Loss: 1.234760
# Train Epoch: 37 [(100%)]	Loss: 2.130326
#
# Test set: Average loss: 1.2302, Accuracy: 5721/10000 (57%)
#
# Train Epoch: 38 [(0%)]	Loss: 1.488494
# Train Epoch: 38 [(100%)]	Loss: 1.121345
#
# Test set: Average loss: 1.1957, Accuracy: 5761/10000 (58%)
#
# Train Epoch: 39 [(0%)]	Loss: 1.852123
# Train Epoch: 39 [(100%)]	Loss: 1.693683
#
# Test set: Average loss: 1.2589, Accuracy: 5522/10000 (55%)
#
# Train Epoch: 40 [(0%)]	Loss: 1.399674
# Train Epoch: 40 [(100%)]	Loss: 1.141920
#
# Test set: Average loss: 1.1846, Accuracy: 5821/10000 (58%)
#
# Train Epoch: 41 [(0%)]	Loss: 1.192738
# Train Epoch: 41 [(100%)]	Loss: 1.117619
#
# Test set: Average loss: 1.1638, Accuracy: 5902/10000 (59%)
#
# Train Epoch: 42 [(0%)]	Loss: 1.211805
# Train Epoch: 42 [(100%)]	Loss: 1.478960
#
# Test set: Average loss: 1.2059, Accuracy: 5758/10000 (58%)
#
# Train Epoch: 43 [(0%)]	Loss: 1.227374
# Train Epoch: 43 [(100%)]	Loss: 1.282458
#
# Test set: Average loss: 1.2151, Accuracy: 5668/10000 (57%)
#
# Train Epoch: 44 [(0%)]	Loss: 1.244802
# Train Epoch: 44 [(100%)]	Loss: 1.360844
#
# Test set: Average loss: 1.2159, Accuracy: 5754/10000 (58%)
#
# Train Epoch: 45 [(0%)]	Loss: 1.437940
# Train Epoch: 45 [(100%)]	Loss: 1.215566
#
# Test set: Average loss: 1.1758, Accuracy: 5879/10000 (59%)
#
# Train Epoch: 46 [(0%)]	Loss: 1.302275
# Train Epoch: 46 [(100%)]	Loss: 1.430942
#
# Test set: Average loss: 1.1794, Accuracy: 5827/10000 (58%)
#
# Train Epoch: 47 [(0%)]	Loss: 1.292175
# Train Epoch: 47 [(100%)]	Loss: 0.971451
#
# Test set: Average loss: 1.1502, Accuracy: 5915/10000 (59%)
#
# Train Epoch: 48 [(0%)]	Loss: 1.186081
# Train Epoch: 48 [(100%)]	Loss: 0.879852
#
# Test set: Average loss: 1.1231, Accuracy: 6045/10000 (60%)
#
# Train Epoch: 49 [(0%)]	Loss: 1.325860
# Train Epoch: 49 [(100%)]	Loss: 1.422198
#
# Test set: Average loss: 1.1487, Accuracy: 5897/10000 (59%)
#
# Train Epoch: 50 [(0%)]	Loss: 1.350643
# Train Epoch: 50 [(100%)]	Loss: 1.154695
#
# Test set: Average loss: 1.1513, Accuracy: 5929/10000 (59%)
